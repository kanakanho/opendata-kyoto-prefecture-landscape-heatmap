# %%
import os
import pandas as pd
import leafmap

# %%
df = pd.read_csv('532572_2456265_misc.csv')
df.head()
# Out:
#    都道府県コード又は市区町村コード  NO 都道府県名               データ名称         データ概要 データ形式      分類  \
# 0            230006   1   愛知県      ひったくり（CSV：4KB）  令和4年中の犯罪発生情報   csv  くらし・安全
# 1            230006   2   愛知県    車上ねらい（CSV：162KB）  令和4年中の犯罪発生情報   csv  くらし・安全
# 2            230006   3   愛知県    部品ねらい（CSV：133KB）  令和4年中の犯罪発生情報   csv  くらし・安全
# 3            230006   4   愛知県  自動販売機ねらい（CSV：31KB）  令和4年中の犯罪発生情報   csv  くらし・安全
# 4            230006   5   愛知県      自動車盗（CSV：93KB）  令和4年中の犯罪発生情報   csv  くらし・安全
#
#                                                  URL  ライセンス  \
# 0  https://www.pref.aichi.jp/police/anzen/toukei/...  CC BY
# 1  https://www.pref.aichi.jp/police/anzen/toukei/...  CC BY
# 2  https://www.pref.aichi.jp/police/anzen/toukei/...  CC BY
# 3  https://www.pref.aichi.jp/police/anzen/toukei/...  CC BY
# 4  https://www.pref.aichi.jp/police/anzen/toukei/...  CC BY
#
#               掲載ページ名                                           掲載ページURL  \
# 0  愛知県警察犯罪オープンデータサイト  https://www.pref.aichi.jp/police/anzen/toukei/...
# 1  愛知県警察犯罪オープンデータサイト  https://www.pref.aichi.jp/police/anzen/toukei/...
# 2  愛知県警察犯罪オープンデータサイト  https://www.pref.aichi.jp/police/anzen/toukei/...
# 3  愛知県警察犯罪オープンデータサイト  https://www.pref.aichi.jp/police/anzen/toukei/...
# 4  愛知県警察犯罪オープンデータサイト  https://www.pref.aichi.jp/police/anzen/toukei/...
#
#    データ提供所属   備考
# 0  愛知県警察本部  NaN
# 1  愛知県警察本部  NaN
# 2  愛知県警察本部  NaN
# 3  愛知県警察本部  NaN
# 4  愛知県警察本部  NaN

# %%
# 都道府県コード又は市区町村コード,NO,都道府県名,データ名称,データ概要,データ形式,分類,URL,ライセンス,掲載ページ名,掲載ページURL,データ提供所属,備考

# データ形式 が csv かつ、データ概要が "景観資源" のものを抽出
df_filtered = df[(df['データ形式'] == 'csv') & (df['データ概要'].str.contains('景観資源'))]

# URL からデータを取得して、"LandscapeResources" ディレクトリに保存

output_dir = 'LandscapeResources'
os.makedirs(output_dir, exist_ok=True)

import requests
from io import BytesIO
import zipfile

# ファイル名のサニタイズ
def sanitize_filename(s):
    return "".join(c if (c.isalnum() or c in (' ','.','_','-')) else '_' for c in str(s)).strip()

# バイトデータから pandas.read_csv を複数エンコーディングで試行
def try_read_csv_from_bytes(b):
    encodings = ['utf-8', 'cp932', 'shift_jis', 'euc_jp', None]
    last_exc = None
    for enc in encodings:
        try:
            if enc is None:
                return pd.read_csv(BytesIO(b))
            else:
                return pd.read_csv(BytesIO(b), encoding=enc)
        except Exception as e:
            last_exc = e
    raise last_exc

for index, row in df_filtered.iterrows():
    url = row['URL']
    prefecture = row.get('都道府県名', 'unknown')
    name = row.get('データ名称', 'data')
    print(f"Processing {url} for {prefecture} - {name}")
    if pd.notna(url) and str(url).strip():
        try:
            resp = requests.get(url, timeout=30)
            resp.raise_for_status()
            content = resp.content

            # ZIPファイル判定: URL末尾、もしくはバイナリを確認
            is_zip = False
            try:
                is_zip = zipfile.is_zipfile(BytesIO(content))
            except Exception:
                is_zip = False

            if is_zip:
                with zipfile.ZipFile(BytesIO(content)) as z:
                    csv_names = [n for n in z.namelist() if n.lower().endswith('.csv')]
                    if not csv_names:
                        raise ValueError('ZIP の中に CSV が見つかりませんでした')
                    with z.open(csv_names[0]) as f:
                        b = f.read()
                        data = try_read_csv_from_bytes(b)
                        csv_part = os.path.splitext(os.path.basename(csv_names[0]))[0]
            else:
                data = try_read_csv_from_bytes(content)
                csv_part = name

            file_name = f"{prefecture}_{csv_part}.csv"
            file_name = sanitize_filename(file_name)
            out_path = os.path.join(output_dir, file_name)
            data.to_csv(out_path, index=False)
            print(f"Saved to {out_path}")
        except Exception as e:
            print(f"Error processing {url}: {e}")
    else:
        print(f"No URL for row {index}")
# Out:
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200538/c200538.csv for 愛知県 - 名古屋市（csv：2.7KB）
# Saved to LandscapeResources/愛知県_名古屋市_csv_2.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200539/c200539.csv for 愛知県 - 豊橋市（csv：1.0KB）
# Saved to LandscapeResources/愛知県_豊橋市_csv_1.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200540/c200540.csv for 愛知県 - 岡崎市（csv：1.2KB）
# Saved to LandscapeResources/愛知県_名古屋市_csv_2.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200539/c200539.csv for 愛知県 - 豊橋市（csv：1.0KB）
# Saved to LandscapeResources/愛知県_豊橋市_csv_1.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200540/c200540.csv for 愛知県 - 岡崎市（csv：1.2KB）
# Saved to LandscapeResources/愛知県_岡崎市_csv_1.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200541/c200541.csv for 愛知県 - 一宮市（csv：2.5KB）
# Saved to LandscapeResources/愛知県_一宮市_csv_2.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200542/c200542.csv for 愛知県 - 瀬戸市（csv：3.0KB）
# Saved to LandscapeResources/愛知県_岡崎市_csv_1.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200541/c200541.csv for 愛知県 - 一宮市（csv：2.5KB）
# Saved to LandscapeResources/愛知県_一宮市_csv_2.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200542/c200542.csv for 愛知県 - 瀬戸市（csv：3.0KB）
# Saved to LandscapeResources/愛知県_瀬戸市_csv_3.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200543/c200543.csv for 愛知県 - 半田市（csv：2.0KB）
# Saved to LandscapeResources/愛知県_半田市_csv_2.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200544/c200544.csv for 愛知県 - 春日井市（csv：3.3KB）
# Saved to LandscapeResources/愛知県_瀬戸市_csv_3.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200543/c200543.csv for 愛知県 - 半田市（csv：2.0KB）
# Saved to LandscapeResources/愛知県_半田市_csv_2.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200544/c200544.csv for 愛知県 - 春日井市（csv：3.3KB）
# Saved to LandscapeResources/愛知県_春日井市_csv_3.3KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200545/c200545.csv for 愛知県 - 豊川市（csv：1.5KB）
# Saved to LandscapeResources/愛知県_豊川市_csv_1.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200546/c200546.csv for 愛知県 - 津島市（csv：0.9KB）
# Saved to LandscapeResources/愛知県_春日井市_csv_3.3KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200545/c200545.csv for 愛知県 - 豊川市（csv：1.5KB）
# Saved to LandscapeResources/愛知県_豊川市_csv_1.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200546/c200546.csv for 愛知県 - 津島市（csv：0.9KB）
# Saved to LandscapeResources/愛知県_津島市_csv_0.9KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200547/c200547.csv for 愛知県 - 碧南市（csv：4.4KB）
# Saved to LandscapeResources/愛知県_碧南市_csv_4.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200548/c200548.csv for 愛知県 - 刈谷市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_津島市_csv_0.9KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200547/c200547.csv for 愛知県 - 碧南市（csv：4.4KB）
# Saved to LandscapeResources/愛知県_碧南市_csv_4.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200548/c200548.csv for 愛知県 - 刈谷市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_刈谷市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200549/c200549.csv for 愛知県 - 豊田市（csv：3.3KB）
# Saved to LandscapeResources/愛知県_豊田市_csv_3.3KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200550/c200550.csv for 愛知県 - 安城市（csv：0.7KB）
# Saved to LandscapeResources/愛知県_刈谷市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200549/c200549.csv for 愛知県 - 豊田市（csv：3.3KB）
# Saved to LandscapeResources/愛知県_豊田市_csv_3.3KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200550/c200550.csv for 愛知県 - 安城市（csv：0.7KB）
# Saved to LandscapeResources/愛知県_安城市_csv_0.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200551/c200551.csv for 愛知県 - 西尾市（csv：0.7KB）
# Saved to LandscapeResources/愛知県_西尾市_csv_0.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200552/c200552.csv for 愛知県 - 蒲郡市（csv：1.2KB）
# Saved to LandscapeResources/愛知県_安城市_csv_0.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200551/c200551.csv for 愛知県 - 西尾市（csv：0.7KB）
# Saved to LandscapeResources/愛知県_西尾市_csv_0.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200552/c200552.csv for 愛知県 - 蒲郡市（csv：1.2KB）
# Saved to LandscapeResources/愛知県_蒲郡市_csv_1.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200553/c200553.csv for 愛知県 - 犬山市（csv：2.8KB）
# Saved to LandscapeResources/愛知県_犬山市_csv_2.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200554/c200554.csv for 愛知県 - 常滑市（csv：1.2KB）
# Saved to LandscapeResources/愛知県_蒲郡市_csv_1.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200553/c200553.csv for 愛知県 - 犬山市（csv：2.8KB）
# Saved to LandscapeResources/愛知県_犬山市_csv_2.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200554/c200554.csv for 愛知県 - 常滑市（csv：1.2KB）
# Saved to LandscapeResources/愛知県_常滑市_csv_1.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200555/c200555.csv for 愛知県 - 江南市（csv：0.8KB）
# Saved to LandscapeResources/愛知県_常滑市_csv_1.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200555/c200555.csv for 愛知県 - 江南市（csv：0.8KB）
# Saved to LandscapeResources/愛知県_江南市_csv_0.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200556/c200556.csv for 愛知県 - 小牧市（csv：2.7KB）
# Saved to LandscapeResources/愛知県_小牧市_csv_2.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200557/c200557.csv for 愛知県 - 稲沢市（csv：4.8KB）
# Saved to LandscapeResources/愛知県_江南市_csv_0.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200556/c200556.csv for 愛知県 - 小牧市（csv：2.7KB）
# Saved to LandscapeResources/愛知県_小牧市_csv_2.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200557/c200557.csv for 愛知県 - 稲沢市（csv：4.8KB）
# Saved to LandscapeResources/愛知県_稲沢市_csv_4.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200558/c200558.csv for 愛知県 - 新城市（csv：3.8KB）
# Saved to LandscapeResources/愛知県_新城市_csv_3.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200559/c200559.csv for 愛知県 - 東海市（csv：0.6KB）
# Saved to LandscapeResources/愛知県_稲沢市_csv_4.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200558/c200558.csv for 愛知県 - 新城市（csv：3.8KB）
# Saved to LandscapeResources/愛知県_新城市_csv_3.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200559/c200559.csv for 愛知県 - 東海市（csv：0.6KB）
# Saved to LandscapeResources/愛知県_東海市_csv_0.6KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200560/c200560.csv for 愛知県 - 大府市（csv：1.7KB）
# Saved to LandscapeResources/愛知県_大府市_csv_1.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200561/c200561.csv for 愛知県 - 知多市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_東海市_csv_0.6KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200560/c200560.csv for 愛知県 - 大府市（csv：1.7KB）
# Saved to LandscapeResources/愛知県_大府市_csv_1.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200561/c200561.csv for 愛知県 - 知多市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_知多市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200562/c200562.csv for 愛知県 - 知立市（csv：0.7KB）
# Saved to LandscapeResources/愛知県_知立市_csv_0.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200563/c200563.csv for 愛知県 - 尾張旭市（csv：2.1KB）
# Saved to LandscapeResources/愛知県_知多市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200562/c200562.csv for 愛知県 - 知立市（csv：0.7KB）
# Saved to LandscapeResources/愛知県_知立市_csv_0.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200563/c200563.csv for 愛知県 - 尾張旭市（csv：2.1KB）
# Saved to LandscapeResources/愛知県_尾張旭市_csv_2.1KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200564/c200564.csv for 愛知県 - 高浜市（csv：1.1KB）
# Saved to LandscapeResources/愛知県_高浜市_csv_1.1KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200565/c200565.csv for 愛知県 - 岩倉市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_尾張旭市_csv_2.1KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200564/c200564.csv for 愛知県 - 高浜市（csv：1.1KB）
# Saved to LandscapeResources/愛知県_高浜市_csv_1.1KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200565/c200565.csv for 愛知県 - 岩倉市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_岩倉市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200566/c200566.csv for 愛知県 - 豊明市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_豊明市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200567/c200567.csv for 愛知県 - 日進市（csv：0.4KB）
# Saved to LandscapeResources/愛知県_岩倉市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200566/c200566.csv for 愛知県 - 豊明市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_豊明市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200567/c200567.csv for 愛知県 - 日進市（csv：0.4KB）
# Saved to LandscapeResources/愛知県_日進市_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200568/c200568.csv for 愛知県 - 田原市（csv：5.6KB）
# Saved to LandscapeResources/愛知県_田原市_csv_5.6KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200569/c200569.csv for 愛知県 - 愛西市（csv：0.6KB）
# Saved to LandscapeResources/愛知県_日進市_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200568/c200568.csv for 愛知県 - 田原市（csv：5.6KB）
# Saved to LandscapeResources/愛知県_田原市_csv_5.6KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200569/c200569.csv for 愛知県 - 愛西市（csv：0.6KB）
# Saved to LandscapeResources/愛知県_愛西市_csv_0.6KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200570/c200570.csv for 愛知県 - 清須市（csv：0.7KB）
# Saved to LandscapeResources/愛知県_愛西市_csv_0.6KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200570/c200570.csv for 愛知県 - 清須市（csv：0.7KB）
# Saved to LandscapeResources/愛知県_清須市_csv_0.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200571/c200571.csv for 愛知県 - 北名古屋市（csv：0.2KB）
# Saved to LandscapeResources/愛知県_北名古屋市_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200572/c200572.csv for 愛知県 - 弥富市（csv：1.1KB）
# Saved to LandscapeResources/愛知県_清須市_csv_0.7KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200571/c200571.csv for 愛知県 - 北名古屋市（csv：0.2KB）
# Saved to LandscapeResources/愛知県_北名古屋市_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200572/c200572.csv for 愛知県 - 弥富市（csv：1.1KB）
# Saved to LandscapeResources/愛知県_弥富市_csv_1.1KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200573/c200573.csv for 愛知県 - みよし市（csv：1.0KB）
# Saved to LandscapeResources/愛知県_みよし市_csv_1.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200574/c200574.csv for 愛知県 - あま市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_弥富市_csv_1.1KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200573/c200573.csv for 愛知県 - みよし市（csv：1.0KB）
# Saved to LandscapeResources/愛知県_みよし市_csv_1.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200574/c200574.csv for 愛知県 - あま市（csv：0.5KB）
# Saved to LandscapeResources/愛知県_あま市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200575/c200575.csv for 愛知県 - 東郷町（csv：0.4KB）
# Saved to LandscapeResources/愛知県_東郷町_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200576/c200576.csv for 愛知県 - 長久手町（csv：1.0KB）
# Saved to LandscapeResources/愛知県_あま市_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200575/c200575.csv for 愛知県 - 東郷町（csv：0.4KB）
# Saved to LandscapeResources/愛知県_東郷町_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200576/c200576.csv for 愛知県 - 長久手町（csv：1.0KB）
# Saved to LandscapeResources/愛知県_長久手町_csv_1.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200577/c200577.csv for 愛知県 - 豊山町（csv：0.4KB）
# Saved to LandscapeResources/愛知県_長久手町_csv_1.0KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200577/c200577.csv for 愛知県 - 豊山町（csv：0.4KB）
# Saved to LandscapeResources/愛知県_豊山町_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200578/c200578.csv for 愛知県 - 大口町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_大口町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200579/c200579.csv for 愛知県 - 扶桑町（csv：0.4KB）
# Saved to LandscapeResources/愛知県_豊山町_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200578/c200578.csv for 愛知県 - 大口町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_大口町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200579/c200579.csv for 愛知県 - 扶桑町（csv：0.4KB）
# Saved to LandscapeResources/愛知県_扶桑町_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200580/c200580.csv for 愛知県 - 大治町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_扶桑町_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200580/c200580.csv for 愛知県 - 大治町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_大治町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200581/c200581.csv for 愛知県 - 蟹江町（csv：0.9KB）
# Saved to LandscapeResources/愛知県_蟹江町_csv_0.9KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200582/c200582.csv for 愛知県 - 飛島村（csv：0.5KB）
# Saved to LandscapeResources/愛知県_大治町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200581/c200581.csv for 愛知県 - 蟹江町（csv：0.9KB）
# Saved to LandscapeResources/愛知県_蟹江町_csv_0.9KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200582/c200582.csv for 愛知県 - 飛島村（csv：0.5KB）
# Saved to LandscapeResources/愛知県_飛島村_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200583/c200583.csv for 愛知県 - 阿久比町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_阿久比町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200584/c200584.csv for 愛知県 - 東浦町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_飛島村_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200583/c200583.csv for 愛知県 - 阿久比町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_阿久比町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200584/c200584.csv for 愛知県 - 東浦町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_東浦町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200585/c200585.csv for 愛知県 - 南知多町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_南知多町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200586/c200586.csv for 愛知県 - 美浜町（csv：0.5KB）
# Saved to LandscapeResources/愛知県_東浦町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200585/c200585.csv for 愛知県 - 南知多町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_南知多町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200586/c200586.csv for 愛知県 - 美浜町（csv：0.5KB）
# Saved to LandscapeResources/愛知県_美浜町_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200587/c200587.csv for 愛知県 - 武豊町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_武豊町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200588/c200588.csv for 愛知県 - 一色町（csv：1.3KB）
# Saved to LandscapeResources/愛知県_美浜町_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200587/c200587.csv for 愛知県 - 武豊町（csv：0.2KB）
# Saved to LandscapeResources/愛知県_武豊町_csv_0.2KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200588/c200588.csv for 愛知県 - 一色町（csv：1.3KB）
# Saved to LandscapeResources/愛知県_一色町_csv_1.3KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200589/c200589.csv for 愛知県 - 吉良町（csv：2.1KB）
# Saved to LandscapeResources/愛知県_吉良町_csv_2.1KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200590/c200590.csv for 愛知県 - 幡豆町（csv：0.8KB）
# Saved to LandscapeResources/愛知県_一色町_csv_1.3KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200589/c200589.csv for 愛知県 - 吉良町（csv：2.1KB）
# Saved to LandscapeResources/愛知県_吉良町_csv_2.1KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200590/c200590.csv for 愛知県 - 幡豆町（csv：0.8KB）
# Saved to LandscapeResources/愛知県_幡豆町_csv_0.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200591/c200591.csv for 愛知県 - 幸田町（csv：0.8KB）
# Saved to LandscapeResources/愛知県_幡豆町_csv_0.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200591/c200591.csv for 愛知県 - 幸田町（csv：0.8KB）
# Saved to LandscapeResources/愛知県_幸田町_csv_0.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200592/c200592.csv for 愛知県 - 設楽町（csv：0.4KB）
# Saved to LandscapeResources/愛知県_設楽町_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200593/c200593.csv for 愛知県 - 東栄町（csv：0.5KB）
# Saved to LandscapeResources/愛知県_幸田町_csv_0.8KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200592/c200592.csv for 愛知県 - 設楽町（csv：0.4KB）
# Saved to LandscapeResources/愛知県_設楽町_csv_0.4KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200593/c200593.csv for 愛知県 - 東栄町（csv：0.5KB）
# Saved to LandscapeResources/愛知県_東栄町_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200594/c200594.csv for 愛知県 - 豊根村（csv：0.8KB）
# Saved to LandscapeResources/愛知県_豊根村_csv_0.8KB_.csv
# Saved to LandscapeResources/愛知県_東栄町_csv_0.5KB_.csv
# Processing https://profile.maps.pref.aichi.jp/map/files/opendata/c200594/c200594.csv for 愛知県 - 豊根村（csv：0.8KB）
# Saved to LandscapeResources/愛知県_豊根村_csv_0.8KB_.csv

# %%
# 'LandscapeResources' の中のcsvファイルを全て統合する
# head フィーチャID,形状(WKT),タイトル,説明,スタイルID,期間開始日時,期間終了日時,作成者,作成日時,更新者,更新日時 
# head に 県,市区町村名,を追加する

import glob

all_files = glob.glob(os.path.join(output_dir, '*.csv'))
combined_data = []

for file in all_files:
    try:
        data = pd.read_csv(file)
        if '都道府県名' not in data.columns:
            data['都道府県名'] = os.path.basename(file).split('_')[0]
        if '市区町村名' not in data.columns:
            data['市区町村名'] = os.path.basename(file).split('_')[1] if len(os.path.basename(file).split('_')) > 1 else 'unknown'
        combined_data.append(data)
    except Exception as e:
        print(f"Error reading {file}: {e}")

if combined_data:
    combined_df = pd.concat(combined_data, ignore_index=True)
    combined_df = combined_df[['都道府県名', '市区町村名'] + [col for col in combined_df.columns if col not in ['都道府県名', '市区町村名']]]
    combined_df.to_csv('combined_landscape_resources.csv', index=False)
    print("Combined data saved to 'combined_landscape_resources.csv'")
# Out:
# Combined data saved to 'combined_landscape_resources.csv'

# %%
# ポイントを可視化する
from shapely.wkt import loads

def extract_coordinates(wkt):
    try:
        point = loads(wkt)
        return point.x, point.y
    except Exception as e:
        print(f"Error parsing WKT: {wkt}, {e}")
        return None, None

combined_df['x'], combined_df['y'] = zip(*combined_df['形状(WKT)'].apply(extract_coordinates))

m = leafmap.Map(center=[35.0, 136.9], zoom=8)
m.add_points_from_xy(
    combined_df,
    x="x",
    y="y",
    color="スタイルID",
    popup=["タイトル", "説明"]
)

m
# Out:
# Map(center=[35.0, 136.9], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
# points の情報を json として保存
"""
{
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "geometry": {
        "type": "Point",
        "coordinates": [136.9, 35.0]
      },
      "properties": {
        "スタイルID": 1,
        "タイトル": "ポイント1",
        "説明": "説明1"
      }
    }
  ]
}
"""

import json

features = []
for _, row in combined_df.iterrows():
    if pd.notna(row['x']) and pd.notna(row['y']):
        feature = {
            "type": "Feature",
            "geometry": {
                "type": "Point",
                "coordinates": [row['x'], row['y']]
            },
            "properties": {
                "スタイルID": row['スタイルID'],
                "タイトル": row['タイトル'],
                "説明": row['説明']
            }
        }
        features.append(feature)

geojson = {
    "type": "FeatureCollection",
    "features": features
}

with open('landscape_resources.geojson', 'w', encoding='utf-8') as f:
    json.dump(geojson, f, ensure_ascii=False, indent=2)
